# %%
import pandas as pd
import numpy as np

data=pd.read_excel('./featureExtraction/py批量提取影像特征结果.xlsx',index_col=0)
data
# Out:
#   diagnostics_Versions_PyRadiomics diagnostics_Versions_Numpy  \
# 0                           v3.0.1                     1.23.5
# 0                           v3.0.1                     1.23.5
# 0                           v3.0.1                     1.23.5
#
#   diagnostics_Versions_SimpleITK diagnostics_Versions_PyWavelet  \
# 0                          2.2.1                          1.4.1
# 0                          2.2.1                          1.4.1
# 0                          2.2.1                          1.4.1
#
#   diagnostics_Versions_Python  \
# 0                      3.10.8
# 0                      3.10.8
# 0                      3.10.8
#
#                   diagnostics_Configuration_Settings  \
# 0  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 0  {'minimumROIDimensions': 2, 'minimumROISize': ...
# 0  {'minimumROIDimensions': 2, 'minimumROISize': ...
#
#   diagnostics_Configuration_EnabledImageTypes  \
# 0                            {'Original': {}}
# ...

# %%
invalid_name = ['diagnostics_Versions_PyRadiomics', 'diagnostics_Versions_Numpy', 'diagnostics_Versions_SimpleITK',
                'diagnostics_Versions_PyWavelet', 'diagnostics_Versions_Python', 'diagnostics_Configuration_Settings',
                  'diagnostics_Image-original_Dimensionality']
data_del = data.drop(invalid_name, axis=1)#删除无意义列
data_del
# Out:
#   diagnostics_Configuration_EnabledImageTypes  \
# 0                            {'Original': {}}
# 0                            {'Original': {}}
# 0                            {'Original': {}}
#
#             diagnostics_Image-original_Hash  \
# 0  5c9ce3ca174f0f8324aa4d277e0fef82dc5ac566
# 0  016951a8f9e8e5de21092d9d62b77262f92e04a5
# 0  f2b8fbc4d5d1da08a1a70e79a301f8a830139438
#
#                   diagnostics_Image-original_Spacing  \
# 0  (0.7812499999999999, 0.7812499999999999, 6.499...
# 0                          (0.664062, 0.664062, 2.1)
# 0  (0.7812499999999999, 0.7812499999999999, 6.499...
#
#   diagnostics_Image-original_Size  diagnostics_Image-original_Mean  \
# 0                  (256, 256, 25)                       385.656408
# 0                   (45, 120, 21)                        63.380441
# 0                  (256, 256, 23)                       236.202177
#
#    diagnostics_Image-original_Minimum  diagnostics_Image-original_Maximum  \
# ...

# %%
print(data_del.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 0 to 0
# Columns: 122 entries, diagnostics_Configuration_EnabledImageTypes to original_ngtdm_Strength
# dtypes: float64(108), int64(4), object(10)
# memory usage: 2.9+ KB
# None

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
data_std=StandardScaler()
data_std=data_std.fit_transform(data_del)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 4
#       2 from sklearn.model_selection import train_test_split
#       3 data_std=StandardScaler()
# ----> 4 data_std=data_std.fit_transform(data_del)
#
# File /usr/local/lib/python3.10/site-packages/sklearn/utils/_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# ...
